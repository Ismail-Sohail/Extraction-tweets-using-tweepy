# %%
consumer_key = 'DRByKwJWEC0h7GAxS9pfoex6G'
consumer_secret = 'Ev33iqe7h9cdzoKOM0E5cLsKrDbd1uvP2JKx4kdukyEyZIJV76' 
access_token = '1617643046870319107-1I7d3vQTq38rR00Y794OFbEgUQ1slA'
access_token_secret = 'JjCV0xPgK9DvhutSHxEFgth6iogp892KZrc4DFraCJJba'

# %%
import tweepy
from tweepy import OAuthHandler
import pandas as pd

# %%
auth = tweepy.OAuthHandler(
    consumer_key,
    consumer_secret,
    access_token,
    access_token_secret
)
api = tweepy.API(auth)

# %%
tweets = api.home_timeline()
# print(public_tweets)
# for tweet in public_tweets:
#     print(tweet.text)
    
data = []
columns = ['User', 'Time', 'Tweet','Like Count']
for tweet in tweets:
    data.append([tweet.user.screen_name,tweet.created_at,tweet.text,tweet])

df = pd.DataFrame(data, columns = columns)
# df.to_CSV('tweets.csv')
df
# Out:
#     User                      Time  \
# 0    CNN 2023-02-04 13:43:07+00:00
# 1    CNN 2023-02-04 13:26:03+00:00
# 2    CNN 2023-02-04 13:15:00+00:00
# 3    CNN 2023-02-04 13:14:39+00:00
# 4   CP24 2023-02-04 13:12:26+00:00
# 5   CP24 2023-02-04 12:59:37+00:00
# 6    CNN 2023-02-04 12:58:50+00:00
# 7   CP24 2023-02-04 12:58:23+00:00
# 8    CNN 2023-02-04 12:41:23+00:00
# 9    CNN 2023-02-04 12:25:38+00:00
# 10   CNN 2023-02-04 12:09:27+00:00
# 11  CP24 2023-02-04 12:00:30+00:00
# 12   CNN 2023-02-04 11:53:13+00:00
# 13  CP24 2023-02-04 11:50:09+00:00
# 14   CNN 2023-02-04 11:37:17+00:00
# 15  CP24 2023-02-04 11:32:43+00:00
# 16   CNN 2023-02-04 11:20:56+00:00
# 17   CNN 2023-02-04 11:04:49+00:00
# 18   CNN 2023-02-04 10:48:44+00:00
# 19   CNN 2023-02-04 10:31:08+00:00
#
#                                                 Tweet  \
# 0   Le Le, a 24-year-old male giant panda, died at...
# 1   Exclusive: Justices used personal email accoun...
# 2   Who do you think is going to win the Super Bow...
# 3   An American volunteer aid worker, Pete Reed, w...
# 4   Sri Lanka marks independence anniversary amid ...
# 5   China balloon: Many questions about suspected ...
# 6   Less than two weeks ago, Gautam Adani was the ...
# 7   Indigenous group talks about reporting system ...
# 8   An unopened first-generation iPhone from 2007 ...
# 9   Shrek is love, Shrek is life, Shrek is… missin...
# 10  Should you feel guilty about not tipping? An e...
# 11  Marit Stiles set to officially take over as On...
# 12  For a player who is usually so lethal in front...
# 13  Would you pay $300 a year for quick access to ...
# 14  Italian anti-Mafia police have arrested anothe...
# 15  'It's not bouncing back:' Workers continue to ...
# 16  Five players were ejected after a fight, in wh...
# 17  Former Sex Pistols frontman John Lydon has fai...
# 18  30-year-old Bobi has been named the world's ol...
# 19  Entrepreneur Melanie Elturk is the owner of Ha...
#
#                                            Like Count
# 0   Status(_api=<tweepy.api.API object at 0x7fa157...
# 1   Status(_api=<tweepy.api.API object at 0x7fa157...
# 2   Status(_api=<tweepy.api.API object at 0x7fa157...
# 3   Status(_api=<tweepy.api.API object at 0x7fa157...
# 4   Status(_api=<tweepy.api.API object at 0x7fa157...
# 5   Status(_api=<tweepy.api.API object at 0x7fa157...
# 6   Status(_api=<tweepy.api.API object at 0x7fa157...
# 7   Status(_api=<tweepy.api.API object at 0x7fa157...
# 8   Status(_api=<tweepy.api.API object at 0x7fa157...
# 9   Status(_api=<tweepy.api.API object at 0x7fa157...
# 10  Status(_api=<tweepy.api.API object at 0x7fa157...
# 11  Status(_api=<tweepy.api.API object at 0x7fa157...
# 12  Status(_api=<tweepy.api.API object at 0x7fa157...
# 13  Status(_api=<tweepy.api.API object at 0x7fa157...
# 14  Status(_api=<tweepy.api.API object at 0x7fa157...
# 15  Status(_api=<tweepy.api.API object at 0x7fa157...
# 16  Status(_api=<tweepy.api.API object at 0x7fa157...
# 17  Status(_api=<tweepy.api.API object at 0x7fa157...
# 18  Status(_api=<tweepy.api.API object at 0x7fa157...
# 19  Status(_api=<tweepy.api.API object at 0x7fa157...

# %%
query = 'elon musk'
tweets2 = tweepy.Cursor(api.search_tweets,query,lang="en").items(100)
tweet_data = []
columns = ['Date','User','Tweet','Retweet Count']
for tweet in tweets2:
    tweet_data.append([tweet.created_at,tweet.user.screen_name,tweet.text,tweet.retweet_count])
df = pd.DataFrame(tweet_data,columns = columns)
df
# Out:
#                         Date             User  \
# 0  2023-02-04 13:43:35+00:00      caputo_john
# 1  2023-02-04 13:43:35+00:00      Techstocks5
# 2  2023-02-04 13:43:34+00:00   ranmarusepicbf
# 3  2023-02-04 13:43:33+00:00        sincity57
# 4  2023-02-04 13:43:31+00:00       anxzjester
# ..                       ...              ...
# 95 2023-02-04 13:38:57+00:00  KnightByzantine
# 96 2023-02-04 13:38:56+00:00       lilOOF2000
# 97 2023-02-04 13:38:52+00:00   kellieteach132
# 98 2023-02-04 13:38:50+00:00          infopap
# 99 2023-02-04 13:38:48+00:00         AIHammer
#
#                                                 Tweet  Retweet Count
# 0   RT @DoctorTurtleboy: Eliza Bleu has become the...            415
# 1   Elon Musk found not guilty of fraud over Tesla...              0
# 2   RT @zucccer: @BreakingBadIrny I hate elon musk...              1
# 3   RT @ChuckCallesto: Who else would love to see ...           1087
# 4   RT @CollinRugg: JUST IN: Jury finds Elon Musk ...           1261
# ..                                                ...            ...
# 95  RT @DoctorTurtleboy: Eliza Bleu has become the...            415
# 96  RT @cb_doge: When Elon Musk was 12 years old, ...           2734
# 97  RT @TO_Resident: Doug Ford is "fixing" Ontario...             73
# 98  RT @OptionsAction: A jury has found that Tesla...             34
# 99  @EMostaque Emad, Who will compete with ChatGPT...              0
#
# [100 rows x 4 columns]
